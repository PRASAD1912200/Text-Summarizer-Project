# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\tpras\\OneDrive\\Documents\\MY_PROJECTS'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\tpras\\OneDrive\\Documents'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
import sys
from pathlib import Path

# Add project root to sys.path
project_root = Path("C:/Users/tpras/OneDrive/Documents/MY_PROJECTS/Text_summarizer_project")
sys.path.append(str(project_root))

# Install the textSummarizer package and dependencies in editable mode
# %pip install -e C:/Users/tpras/OneDrive/Documents/MY_PROJECTS/Text_summarizer_project
# %pip install python-box ensure pyYAML
# Out:
# Obtaining file:///C:/Users/tpras/OneDrive/Documents/MY_PROJECTS/Text_summarizer_project
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for textSummarizer (pyproject.toml): started
#   Building editable for textSummarizer (pyproject.toml): finished with status 'done'
#   Created wheel for textSummarizer: filename=textsummarizer-0.0.0-0.editable-py3-none-any.whl size=1589 sha256=758e432089c153c0923c9556f7e115f3e69e28b3db335481d5618161633da86c
# ...

# %%
import sys
from pathlib import Path

# Add project root to sys.path
project_root = Path("C:/Users/tpras/OneDrive/Documents/MY_PROJECTS/Text_summarizer_project")
sys.path.insert(0, str(project_root / "src"))

from textSummarizer.utils.common import read_yaml
from textSummarizer.entity import DataIngestionConfig

# Use absolute paths directly
config_file_path = project_root / "config" / "config.yaml"
params_file_path = project_root / "params.yaml"

# Load config
config = read_yaml(config_file_path)
params = read_yaml(params_file_path)

# Get data ingestion config
data_ingestion_config = DataIngestionConfig(
    root_dir=Path(config.data_ingestion.root_dir),
    source_URL=config.data_ingestion.source_URL,
    local_data_file=Path(config.data_ingestion.local_data_file),
    unzip_dir=Path(config.data_ingestion.unzip_dir)
)
print(data_ingestion_config)
# Out:
# [2026-04-22 22:11:29,982:INFO:common:yaml file: C:\Users\tpras\OneDrive\Documents\MY_PROJECTS\Text_summarizer_project\config\config.yaml loaded successfully]
# [2026-04-22 22:11:29,984:INFO:common:yaml file: C:\Users\tpras\OneDrive\Documents\MY_PROJECTS\Text_summarizer_project\params.yaml loaded successfully]
# ---------------------------------------------------------------------------
# BoxValueError                             Traceback (most recent call last)
# File ~\OneDrive\Documents\MY_PROJECTS\Text_summarizer_project\src\textSummarizer\utils\common.py:30, in read_yaml(path_to_yaml)
#      29         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# ---> 30         return ConfigBox(content)
#      31 except BoxValueError:
#
# File c:\Users\tpras\OneDrive\Documents\MY_PROJECTS\Text_summarizer_project\.venv\Lib\site-packages\box\box.py:301, in box.box.Box.__init__()
#
# BoxValueError: First argument must be mapping or iterable
#
# ...
